# %%
from pathlib import Path
import pandas as pd

data_dir = Path("../data")

# %%
csv_data = data_dir / 'data.csv'

# %%
df = pd.read_csv(csv_data)

# %%
df
# Out:
#              date quarter sp500 sp500cap bist100 bist100cap bistall  \
# 0      1964-03-31  1964Q1    79  357,907     NaN        NaN     NaN
# 1      1964-04-01  1964Q2    79  357,907     NaN        NaN     NaN
# 2      1964-04-02  1964Q2    80  357,907     NaN        NaN     NaN
# 3      1964-04-03  1964Q2    80  357,907     NaN        NaN     NaN
# 4      1964-04-06  1964Q2    80  357,907     NaN        NaN     NaN
# ...           ...     ...   ...      ...     ...        ...     ...
# 16075  2022-11-06  2022Q4   NaN      NaN     NaN        NaN     NaN
# 16076  2022-11-12  2022Q4   NaN      NaN     NaN        NaN     NaN
# 16077  2022-11-13  2022Q4   NaN      NaN     NaN        NaN     NaN
# 16078  2022-11-19  2022Q4   NaN      NaN     NaN        NaN     NaN
# 16079  2022-11-20  2022Q4   NaN      NaN     NaN        NaN     NaN
#
#       bistallcap       btc      eth gold  rate  cpi  usdtry  eurtry
# 0            NaN       NaN      NaN  NaN   NaN  NaN     NaN     NaN
# ...

# %%
df.bist100.info
# Out:
# <bound method Series.info of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 16075    NaN
# 16076    NaN
# 16077    NaN
# 16078    NaN
# 16079    NaN
# Name: bist100, Length: 16080, dtype: object>

# %%
def change_type(v: str | float):
    if isinstance(v, float):
        return v
    return v.strip('').strip(' ').replace(' ', '').strip().replace(',','.')

# %%
df.bist100 = df.bist100.apply(change_type)

# %%
df.bist100 = df.bist100.astype(float)

# %%
df
# Out:
#              date quarter sp500 sp500cap  bist100 bist100cap bistall  \
# 0      1964-03-31  1964Q1    79  357,907      NaN        NaN     NaN
# 1      1964-04-01  1964Q2    79  357,907      NaN        NaN     NaN
# 2      1964-04-02  1964Q2    80  357,907      NaN        NaN     NaN
# 3      1964-04-03  1964Q2    80  357,907      NaN        NaN     NaN
# 4      1964-04-06  1964Q2    80  357,907      NaN        NaN     NaN
# ...           ...     ...   ...      ...      ...        ...     ...
# 16075  2022-11-06  2022Q4   NaN      NaN      NaN        NaN     NaN
# 16076  2022-11-12  2022Q4   NaN      NaN      NaN        NaN     NaN
# 16077  2022-11-13  2022Q4   NaN      NaN      NaN        NaN     NaN
# 16078  2022-11-19  2022Q4   NaN      NaN      NaN        NaN     NaN
# 16079  2022-11-20  2022Q4   NaN      NaN      NaN        NaN     NaN
#
#       bistallcap       btc      eth gold  rate  cpi  usdtry  eurtry
# 0            NaN       NaN      NaN  NaN   NaN  NaN     NaN     NaN
# ...

# %%
df.set_index(df.date)
# Out:
#                   date quarter sp500 sp500cap  bist100 bist100cap bistall  \
# date
# 1964-03-31  1964-03-31  1964Q1    79  357,907      NaN        NaN     NaN
# 1964-04-01  1964-04-01  1964Q2    79  357,907      NaN        NaN     NaN
# 1964-04-02  1964-04-02  1964Q2    80  357,907      NaN        NaN     NaN
# 1964-04-03  1964-04-03  1964Q2    80  357,907      NaN        NaN     NaN
# 1964-04-06  1964-04-06  1964Q2    80  357,907      NaN        NaN     NaN
# ...                ...     ...   ...      ...      ...        ...     ...
# 2022-11-06  2022-11-06  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-12  2022-11-12  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-13  2022-11-13  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-19  2022-11-19  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-20  2022-11-20  2022Q4   NaN      NaN      NaN        NaN     NaN
#
#            bistallcap       btc      eth gold  rate  cpi  usdtry  eurtry
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16080, step=1)

# %%
df.index = pd.to_datetime(df.date)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                   date quarter sp500 sp500cap  bist100 bist100cap bistall  \
# date
# 1964-03-31  1964-03-31  1964Q1    79  357,907      NaN        NaN     NaN
# 1964-04-01  1964-04-01  1964Q2    79  357,907      NaN        NaN     NaN
# 1964-04-02  1964-04-02  1964Q2    80  357,907      NaN        NaN     NaN
# 1964-04-03  1964-04-03  1964Q2    80  357,907      NaN        NaN     NaN
# 1964-04-06  1964-04-06  1964Q2    80  357,907      NaN        NaN     NaN
# ...                ...     ...   ...      ...      ...        ...     ...
# 2022-11-06  2022-11-06  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-12  2022-11-12  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-13  2022-11-13  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-19  2022-11-19  2022Q4   NaN      NaN      NaN        NaN     NaN
# 2022-11-20  2022-11-20  2022Q4   NaN      NaN      NaN        NaN     NaN
#
#            bistallcap       btc      eth gold  rate  cpi  usdtry  eurtry
# ...

# %%
ror_daily = df.bist100.pct_change()

# %%
ror_daily
# Out:
# date
# 1964-03-31    NaN
# 1964-04-01    NaN
# 1964-04-02    NaN
# 1964-04-03    NaN
# 1964-04-06    NaN
#              ...
# 2022-11-06    0.0
# 2022-11-12    0.0
# 2022-11-13    0.0
# 2022-11-19    0.0
# 2022-11-20    0.0
# Name: bist100, Length: 16079, dtype: float64

# %%
ror_weekly = df.bist100.resample('W').ffill().pct_change()

# %%
ror_weekly
# Out:
# date
# 1964-04-05         NaN
# 1964-04-12         NaN
# 1964-04-19         NaN
# 1964-04-26         NaN
# 1964-05-03         NaN
#                 ...
# 2022-11-27    0.443293
# 2022-12-04    0.018260
# 2022-12-11    0.008463
# 2022-12-18    0.041758
# 2022-12-25    0.034139
# Freq: W-SUN, Name: bist100, Length: 3065, dtype: float64

# %%
ror_monthly = df.bist100.resample('M').ffill().pct_change()

# %%
ror_monthly
# Out:
# date
# 1964-03-31         NaN
# 1964-04-30         NaN
# 1964-05-31         NaN
# 1964-06-30         NaN
# 1964-07-31         NaN
#                 ...
# 2022-08-31    0.223380
# 2022-09-30    0.002838
# 2022-10-31    0.251258
# 2022-11-30    0.251068
# 2022-12-31    0.083166
# Freq: M, Name: bist100, Length: 706, dtype: float64

# %%
ror_bist100 = pd.DataFrame()

# %%
ror_bist100
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ror_bist100['daily'] = ror_daily

# %%
ror_bist100
# Out:
#             daily
# date
# 1964-03-31    NaN
# 1964-04-01    NaN
# 1964-04-02    NaN
# 1964-04-03    NaN
# 1964-04-06    NaN
# ...           ...
# 2022-11-06    0.0
# 2022-11-12    0.0
# 2022-11-13    0.0
# 2022-11-19    0.0
# 2022-11-20    0.0
#
# [16079 rows x 1 columns]

# %%
ror_bist100['weekly'] = ror_weekly

# %%
ror_bist100
# Out:
#             daily  weekly
# date
# 1964-03-31    NaN     NaN
# 1964-04-01    NaN     NaN
# 1964-04-02    NaN     NaN
# 1964-04-03    NaN     NaN
# 1964-04-06    NaN     NaN
# ...           ...     ...
# 2022-11-06    0.0     0.0
# 2022-11-12    0.0     NaN
# 2022-11-13    0.0     0.0
# 2022-11-19    0.0     NaN
# 2022-11-20    0.0     0.0
#
# [16079 rows x 2 columns]

# %%
ror_weekly
# Out:
# date
# 1964-04-05         NaN
# 1964-04-12         NaN
# 1964-04-19         NaN
# 1964-04-26         NaN
# 1964-05-03         NaN
#                 ...
# 2022-11-27    0.443293
# 2022-12-04    0.018260
# 2022-12-11    0.008463
# 2022-12-18    0.041758
# 2022-12-25    0.034139
# Freq: W-SUN, Name: bist100, Length: 3065, dtype: float64

# %%
ror_bist100['monthly'] = ror_monthly

# %%
ror_bist100
# Out:
#             daily  weekly  monthly
# date
# 1964-03-31    NaN     NaN      NaN
# 1964-04-01    NaN     NaN      NaN
# 1964-04-02    NaN     NaN      NaN
# 1964-04-03    NaN     NaN      NaN
# 1964-04-06    NaN     NaN      NaN
# ...           ...     ...      ...
# 2022-11-06    0.0     0.0      NaN
# 2022-11-12    0.0     NaN      NaN
# 2022-11-13    0.0     0.0      NaN
# 2022-11-19    0.0     NaN      NaN
# 2022-11-20    0.0     0.0      NaN
#
# [16079 rows x 3 columns]

# %%
period_1990_1999 = pd.date_range(start='1990-01-01', end='1999-12-31')

# %%
r1990_1999 = ror_bist100.loc[period_1990_1999, 'daily']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 r1990_1999 = ror_bist100.loc[period_1990_1999, 'daily']
#
# File ~/Developer/SDKs/dataspell/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/Developer/SDKs/dataspell/lib/python3.10/site-packages/pandas/core/indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1245 with suppress(IndexingError):
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
#    1249 # no multi-index, so validate all of the indexers
# ...
